# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

import xgboost as xgb
from pytorch_tabnet.tab_model import TabNetClassifier

import tensorflow as tf
import torch
import keras
# Model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.initializers import RandomNormal, Constant

# Metrics
from sklearn.metrics import roc_auc_score, average_precision_score, balanced_accuracy_score
from sklearn.metrics import make_scorer

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, QuantileTransformer, RobustScaler, StandardScaler,MinMaxScaler
from tensorflow.keras.optimizers  import Adam, Adagrad, SGD, RMSprop

from sklearn.metrics import confusion_matrix, roc_curve
from sklearn.model_selection import train_test_split 

import fairness_helpers as fh
import utilities
import global_variables as gv

import shap

# %% [markdown]
# #### load data

# %%
df = pd.read_csv('data/binary_full.csv')
pd.set_option('display.max_columns', None)
df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# #### retreive model

# %%
model = keras.models.load_model('saved_models/mlp_binary_1.h5')
model.compile(loss='binary_crossentropy', #categorical_hinge
              optimizer=SGD(learning_rate=0.0005),
              metrics=['acc',tf.keras.metrics.AUC(), tf.keras.metrics.Recall()])

# %% [markdown]
# #### split data and predict probabilities on test dataset

# %%
X_train, X_val,  X_test, y_train, y_val, y_test = utilities.process_features(df, 'CVD', RobustScaler(), one_hot=True, val=True, test_size=0.3)

# y_prob = model.predict(X_test) # outputs probablity assigned to Class 1
# y_prob

# %%
one_count=0
zero_count=0
one_total=0
zero_total=0
for i, val in zip(y_test, y_prob):
    if i == 1:
        one_count+=1
        one_total+=val
    elif i==0:
        zero_count+=1
        zero_total+=val

print(one_total/one_count)
print(zero_total/zero_count)
# Out:
# [0.5731583]
# [0.42829001]

# %% [markdown]
# #### some functions to evaluate model predictions

# %%
def confusion_eval2(predictions, X_test, y_test, threshold=0.5):
    """
    Takes in model, testing data, and decision threshold and outputs prediction performance (confusion matrix,
    sensitivity, specificity, and accuracy)
    """
    y_predicted = (predictions >= threshold)

    conf_mat = confusion_matrix(y_test, y_predicted)
    print(conf_mat)
    total = sum(sum(conf_mat))
    sensitivity = conf_mat[0, 0]/(conf_mat[0, 0] + conf_mat[1, 0])
    specificity = conf_mat[1, 1]/(conf_mat[1, 1] + conf_mat[0, 1])
    accuracy = (conf_mat[0, 0] + conf_mat[1, 1])/total
    bal_accuracy = balanced_accuracy_score(y_test, y_predicted)
    print('specificity : ', specificity)
    print('sensitivity : ', sensitivity)
    print('accuracy : ', accuracy)
    print('balanced accuracy: ', bal_accuracy)
    return conf_mat, sensitivity, specificity, accuracy, bal_accuracy

# %% [markdown]
# ### let's figure out the best threshold to minimize false negatives!
#
# > Since this problem is a case of medical diagnostics, we care way more about correctly diagnosing the people who actually have CVDs so that they can get treatment, therefore we are willing to allow a few more false positive cases to ensure the best ultimate health outcomes for everyone. (focus on maximizing Sensitivity)

# %% [markdown]
# #### optimal threshold for ROC Curve

# %%
# calculate scores
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# plot the roc curve for the model
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Logistic')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
# show the plot
plt.show()

# %%
y_prob = model.predict(X_test)
test_thresholds=np.arange(0,1,0.01)
df_results = pd.DataFrame(columns = ['threshold', 'specificity', 'sensitivity', 'accuracy', 'balanced accuracy'])
for threshold in test_thresholds:
    mat, sens,spec, acc, bal = fh.confusion_eval2(y_prob, X_test, y_test, threshold=threshold)
    
    df_new = pd.DataFrame({'threshold':threshold, 'specificity':spec, 'sensitivity':sens, 'accuracy':acc, 'balanced accuracy':bal}, index=[0])
    df_results = pd.concat([df_results,df_new])
# Out:
# 4711/4711 [==============================] - 32s 7ms/step
# [[     0 136668]
#  [     0  14077]]
# specificity :  0.09338286510332018
# sensitivity :  nan
# accuracy :  0.09338286510332018
# balanced accuracy:  0.5
# [[     0 136668]
#  [     0  14077]]
# specificity :  0.09338286510332018
# sensitivity :  nan
# accuracy :  0.09338286510332018
# balanced accuracy:  0.5
# [[     0 136668]
#  [     0  14077]]
# specificity :  0.09338286510332018
# sensitivity :  nan
# accuracy :  0.09338286510332018
# balanced accuracy:  0.5
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# [[     0 136668]
#  [     0  14077]]
# specificity :  0.09338286510332018
# sensitivity :  nan
# accuracy :  0.09338286510332018
# balanced accuracy:  0.5
# [[     0 136668]
#  [     0  14077]]
# specificity :  0.09338286510332018
# sensitivity :  nan
# accuracy :  0.09338286510332018
# balanced accuracy:  0.5
# [[     0 136668]
#  [     0  14077]]
# specificity :  0.09338286510332018
# sensitivity :  nan
# accuracy :  0.09338286510332018
# balanced accuracy:  0.5
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# [[     0 136668]
#  [     0  14077]]
# specificity :  0.09338286510332018
# sensitivity :  nan
# accuracy :  0.09338286510332018
# balanced accuracy:  0.5
# [[     0 136668]
#  [     0  14077]]
# specificity :  0.09338286510332018
# sensitivity :  nan
# accuracy :  0.09338286510332018
# balanced accuracy:  0.5
# [[     0 136668]
#  [     0  14077]]
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# specificity :  0.09338286510332018
# sensitivity :  nan
# accuracy :  0.09338286510332018
# balanced accuracy:  0.5
# [[     2 136666]
#  [     0  14077]]
# specificity :  0.09338410407116748
# sensitivity :  1.0
# accuracy :  0.0933961325417095
# balanced accuracy:  0.5000073170017854
# [[    14 136654]
#  [     0  14077]]
# specificity :  0.0933915385687085
# sensitivity :  1.0
# accuracy :  0.0934757371720455
# balanced accuracy:  0.5000512190124975
# [[    38 136630]
#  [     1  14076]]
# specificity :  0.09340039547197855
# sensitivity :  0.9743589743589743
# accuracy :  0.09362831271352284
# balanced accuracy:  0.5001035041023311
# [[   131 136537]
#  [     2  14075]]
# specificity :  0.09345204897352137
# sensitivity :  0.9849624060150376
# accuracy :  0.09423861487943215
# balanced accuracy:  0.5004082257537592
# [[   343 136325]
#  [     5  14072]]
# specificity :  0.0935656961242578
# sensitivity :  0.985632183908046
# accuracy :  0.09562506219111745
# balanced accuracy:  0.5010772711482345
# [[   710 135958]
#  [    15  14062]]
# specificity :  0.09373416877749634
# sensitivity :  0.9793103448275862
# accuracy :  0.09799329994361339
# balanced accuracy:  0.5020647516599406
# [[  1288 135380]
#  [    30  14047]]
# specificity :  0.09400576870311256
# sensitivity :  0.9772382397572079
# accuracy :  0.10172808385021062
# balanced accuracy:  0.5036465812020483
# [[  2123 134545]
#  [    37  14040]]
# specificity :  0.09449136857690885
# sensitivity :  0.9828703703703704
# accuracy :  0.10722080334339447
# balanced accuracy:  0.5064527969262975
# [[  3219 133449]
#  [    51  14026]]
# specificity :  0.09510764536362096
# sensitivity :  0.9844036697247707
# accuracy :  0.11439848751202361
# balanced accuracy:  0.5099652488624009
# [[  4568 132100]
#  [    71  14006]]
# specificity :  0.09586190847740682
# sensitivity :  0.9846949773658116
# accuracy :  0.12321470032173538
# balanced accuracy:  0.5141901879348076
# [[  6253 130415]
#  [    97  13980]]
# specificity :  0.09681775684753627
# sensitivity :  0.9847244094488189
# accuracy :  0.13422004046568708
# balanced accuracy:  0.5194312697176097
# [[  8131 128537]
#  [   138  13939]]
# specificity :  0.0978340211684775
# sensitivity :  0.9833111621719676
# accuracy :  0.14640618262628943
# balanced accuracy:  0.5248456581988399
# [[ 10203 126465]
#  [   195  13882]]
# specificity :  0.098911982443515
# sensitivity :  0.9812463935372187
# accuracy :  0.15977312680354241
# balanced accuracy:  0.5304014929478003
# [[ 12521 124147]
#  [   244  13833]]
# specificity :  0.1002536599507175
# sensitivity :  0.9808852330591461
# accuracy :  0.17482503565624066
# balanced accuracy:  0.5371414703690827
# [[ 14971 121697]
#  [   302  13775]]
# specificity :  0.10168152828628794
# sensitivity :  0.9802265435736267
# accuracy :  0.19069289196988293
# balanced accuracy:  0.5440446995238833
# [[ 17627 119041]
#  [   368  13709]]
# specificity :  0.1032693032015066
# sensitivity :  0.9795498749652681
# accuracy :  0.20787422468406913
# sensitivity :  0.9131850096362732
# accuracy :  0.8983515207801254
# balanced accuracy:  0.5377840202851886
# [[134608   2060]
#  [ 12964   1113]]
# specificity :  0.350772139930665
# sensitivity :  0.9121513566259182
# accuracy :  0.9003350028193307
# balanced accuracy:  0.5319960590213596
# [[135062   1606]
#  [ 13184    893]]
# specificity :  0.3573429371748699
# sensitivity :  0.911066740417954
# accuracy :  0.9018872931108827
# balanced accuracy:  0.5258428534767154
# [[135485   1183]
#  [ 13414    663]]
# specificity :  0.3591549295774648
# sensitivity :  0.9099120880596915
# accuracy :  0.9031676009154532
# balanced accuracy:  0.519221045088493
# [[135852    816]
#  [ 13576    501]]
# specificity :  0.3804100227790433
# sensitivity :  0.909146880102792
# accuracy :  0.9045275133503599
# balanced accuracy:  0.5148096479984372
# [[136108    560]
#  [ 13706    371]]
# specificity :  0.39849624060150374
# sensitivity :  0.9085132230632651
# accuracy :  0.9053633619688879
# balanced accuracy:  0.511128763120192
# [[136278    390]
#  [ 13814    263]]
# specificity :  0.40275650842266464
# sensitivity :  0.9079631159555472
# accuracy :  0.9057746525589572
# balanced accuracy:  0.5079146636601685
# [[136443    225]
#  [ 13911    166]]
# specificity :  0.42455242966751916
# sensitivity :  0.9074783510914243
# accuracy :  0.9062257454641945
# balanced accuracy:  0.5050729799431776
# [[136544    124]
#  [ 13985     92]]
# specificity :  0.42592592592592593
# sensitivity :  0.9070943140524417
# accuracy :  0.9064048558824505
# balanced accuracy:  0.5028140875956378
# [[136603     65]
#  [ 14019     58]]
# specificity :  0.4715447154471545
# sensitivity :  0.9069259470728047
# accuracy :  0.9065706988623171
# balanced accuracy:  0.5018222954742274
# [[136637     31]
#  [ 14049     28]]
# specificity :  0.4745762711864407
# sensitivity :  0.9067663883837914
# accuracy :  0.9065972337390958
# balanced accuracy:  0.5008811165568622
# [[136651     17]
#  [ 14069      8]]
# specificity :  0.32
# sensitivity :  0.9066547239915075
# accuracy :  0.9065574314239279
# balanced accuracy:  0.5002219569375488
# [[136662      6]
#  [ 14072      5]]
# specificity :  0.45454545454545453
# sensitivity :  0.9066434911831438
# accuracy :  0.9066105011774852
# balanced accuracy:  0.5001556436525966
# [[136663      5]
#  [ 14075      2]]
# specificity :  0.2857142857142857
# sensitivity :  0.9066260664198809
# accuracy :  0.9065972337390958
# balanced accuracy:  0.5000527453587177
# [[136666      2]
#  [ 14076      1]]
# specificity :  0.3333333333333333
# sensitivity :  0.9066219102837961
# accuracy :  0.9066105011774852
# balanced accuracy:  0.5000282019298051
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# invalid value encountered in longlong_scalars

# %%
df_results

# %% [markdown]
# #### plot threshold results

# %%
sns.set_style("darkgrid")

# plot lines
plt.figure(figsize=(8,4))
plt.plot(df_results['threshold'], df_results['accuracy'], label = "accuracy")
plt.plot(df_results['threshold'], df_results['balanced accuracy'], label = "balanced acc")
plt.plot(df_results['threshold'], df_results['specificity'], label = "specificity")
plt.plot(df_results['threshold'], df_results['sensitivity'], label = "sensitivity")
# single line
plt.vlines(x = 0.5, ymin = 0, ymax = 1.0,
           colors = 'dimgray',
           linestyle='--')
plt.vlines(x = 0.85, ymin = 0, ymax = 1.0,
           colors = 'dimgray',
           linestyle='--')
# plt.legend(loc='upper left')
plt.legend(loc='lower right')
plt.title('Decision Threshold Optimization: MLP', fontsize=13, fontweight='bold')
plt.xlabel('Threshold', fontsize=12)
plt.savefig('charts/models/MLP/mlp_threshold_balanced.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### build SHAP explainer

# %%
explainer = shap.KernelExplainer(model.predict,X_train)

# %% [markdown]
# ## XGBoost Model

# %%
model_xgb = xgb.Booster()
model_xgb.load_model("saved_models/boost_1.json")

# %%
from xgboost import XGBClassifier

n_estimators = 1000

clf_xgb = XGBClassifier(max_depth=8,
    learning_rate=0.01,
    n_estimators=n_estimators,
    verbosity=0,
    silent=None,
    objective="binary:logistic",
    booster='gbtree',
    n_jobs=-1,
    nthread=None,
    gamma=0,
    min_child_weight=1,
    max_delta_step=0,
    subsample=0.7,
    colsample_bytree=1,
    colsample_bylevel=1,
    colsample_bynode=1,
    reg_alpha=0,
    reg_lambda=1,
    scale_pos_weight=1,
    base_score=0.5,
    random_state=0,
    seed=None,)

clf_xgb.fit(X_train, y_train,
            eval_set=[(X_val, y_val)],
            early_stopping_rounds=40,
            verbose=20)
# Out:
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-logloss:0.68621
# [20]	validation_0-logloss:0.57213
# [40]	validation_0-logloss:0.49216
# [60]	validation_0-logloss:0.43436
# [80]	validation_0-logloss:0.39187
# [100]	validation_0-logloss:0.36026
# [120]	validation_0-logloss:0.33659
# [140]	validation_0-logloss:0.31880
# [160]	validation_0-logloss:0.30542
# [180]	validation_0-logloss:0.29534
# [200]	validation_0-logloss:0.28776
# [220]	validation_0-logloss:0.28210
# [240]	validation_0-logloss:0.27787
# [260]	validation_0-logloss:0.27471
# [280]	validation_0-logloss:0.27235
# [300]	validation_0-logloss:0.27063
# [320]	validation_0-logloss:0.26935
# [340]	validation_0-logloss:0.26840
# [360]	validation_0-logloss:0.26769
# [380]	validation_0-logloss:0.26718
# [400]	validation_0-logloss:0.26681
# [420]	validation_0-logloss:0.26654
# [440]	validation_0-logloss:0.26632
# [460]	validation_0-logloss:0.26612
# [480]	validation_0-logloss:0.26599
# [500]	validation_0-logloss:0.26587
# [520]	validation_0-logloss:0.26573
# [540]	validation_0-logloss:0.26565
# [560]	validation_0-logloss:0.26557
# [580]	validation_0-logloss:0.26548
# [600]	validation_0-logloss:0.26543
# [620]	validation_0-logloss:0.26538
# [640]	validation_0-logloss:0.26536
# [660]	validation_0-logloss:0.26532
# [680]	validation_0-logloss:0.26528
# [700]	validation_0-logloss:0.26525
# [720]	validation_0-logloss:0.26523
# [740]	validation_0-logloss:0.26522
# [760]	validation_0-logloss:0.26519
# [780]	validation_0-logloss:0.26516
# [800]	validation_0-logloss:0.26513
# [820]	validation_0-logloss:0.26511
# [840]	validation_0-logloss:0.26507
# [860]	validation_0-logloss:0.26507
# [880]	validation_0-logloss:0.26506
# [900]	validation_0-logloss:0.26505
# [920]	validation_0-logloss:0.26504
# [940]	validation_0-logloss:0.26503
# [960]	validation_0-logloss:0.26502
# [980]	validation_0-logloss:0.26504
# [999]	validation_0-logloss:0.26502
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.01, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=8, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=1000,
#               n_jobs=-1, nthread=-1, num_parallel_tree=1, predictor='auto',
#               random_state=0, reg_alpha=0, ...)

# %%
y_boost_pred = clf_xgb.predict_proba(X_test)[:,1]

# %%
from numpy import savetxt

y_boost_pred
savetxt('y_boost_pred.csv', y_boost_pred, delimiter=',')

# %%
test_thresholds=np.arange(0,1,0.02)
df_results2 = pd.DataFrame(columns = ['threshold', 'specificity', 'sensitivity', 'accuracy', 'balanced accuracy'])
for threshold in test_thresholds:
    mat, sens,spec, acc, bal = fh.confusion_eval2(y_boost_pred, X_test, y_test, threshold=threshold)
    
    df_new = pd.DataFrame({'threshold':threshold, 'specificity':spec, 'sensitivity':sens, 'accuracy':acc, 'balanced accuracy':bal}, index=[0])
    df_results2 = pd.concat([df_results2,df_new])
# Out:
# [[     0 136668]
#  [     0  14077]]
# specificity :  0.09338286510332018
# sensitivity :  nan
# accuracy :  0.09338286510332018
# balanced accuracy:  0.5
# [[ 16103 120565]
#  [   282  13795]]
# specificity :  0.10267192616850253
# sensitivity :  0.9827891364052487
# accuracy :  0.1983349364821387
# balanced accuracy:  0.5488965011662013
# [[55042 81626]
#  [ 1503 12574]]
# invalid value encountered in longlong_scalars
# specificity :  0.13348195329087048
# sensitivity :  0.9734194004774958
# accuracy :  0.44854555706656934
# balanced accuracy:  0.6479862519539961
# [[76833 59835]
#  [ 2701 11376]]
# specificity :  0.15975060032860092
# sensitivity :  0.9660396811426559
# accuracy :  0.5851537364423364
# balanced accuracy:  0.6851569648607957
# [[91267 45401]
#  [ 3845 10232]]
# specificity :  0.18391961605521903
# sensitivity :  0.9595739759441501
# accuracy :  0.673315864539454
# balanced accuracy:  0.6973301090060802
# [[101170  35498]
#  [  4868   9209]]
# specificity :  0.2059856398326884
# sensitivity :  0.9540919293083612
# accuracy :  0.7322232909880925
# balanced accuracy:  0.6972243763291128
# [[108215  28453]
#  [  5797   8280]]
# specificity :  0.2254103939237198
# sensitivity :  0.9491544749675472
# accuracy :  0.7727951175826727
# balanced accuracy:  0.6900014276703932
# [[113643  23025]
#  [  6659   7418]]
# specificity :  0.24366849522057615
# sensitivity :  0.9446476367807684
# accuracy :  0.8030846794255199
# balanced accuracy:  0.6792424514847852
# [[117942  18726]
#  [  7413   6664]]
# specificity :  0.26246553761323355
# sensitivity :  0.940863946392246
# accuracy :  0.8266012139706126
# balanced accuracy:  0.6681890724031262
# [[121468  15200]
#  [  8195   5882]]
# specificity :  0.2790057869272365
# sensitivity :  0.9367976986495762
# accuracy :  0.8448041394407775
# balanced accuracy:  0.653313142046895
# [[124445  12223]
#  [  8943   5134]]
# specificity :  0.2957884427032321
# sensitivity :  0.9329549884547336
# accuracy :  0.8595906995256891
# balanced accuracy:  0.6376363383746639
# [[126906   9762]
#  [  9643   4434]]
# specificity :  0.31234150464919697
# sensitivity :  0.9293806618869417
# accuracy :  0.8712726790274967
# balanced accuracy:  0.6217766569581586
# [[128869   7799]
#  [ 10253   3824]]
# specificity :  0.3290028391981416
# sensitivity :  0.926302094564483
# accuracy :  0.8802481010978805
# balanced accuracy:  0.6072917459402501
# [[130521   6147]
#  [ 10809   3268]]
# specificity :  0.34710568242166756
# sensitivity :  0.9235194226278922
# sensitivity :  0.9069336767204758
# accuracy :  0.9067697104381571
# balanced accuracy:  0.5018683296396118
# [[136644     24]
#  [ 14039     38]]
# specificity :  0.6129032258064516
# sensitivity :  0.9068308966505844
# accuracy :  0.9067100069654052
# balanced accuracy:  0.5012619153790163
# [[136652     16]
#  [ 14051     26]]
# specificity :  0.6190476190476191
# sensitivity :  0.9067636344332893
# accuracy :  0.9066834720886265
# balanced accuracy:  0.5008649562070712
# [[136656     12]
#  [ 14060     17]]
# specificity :  0.5862068965517241
# sensitivity :  0.9067119615701054
# accuracy :  0.9066503034926532
# balanced accuracy:  0.5005599198263271
# [[136661      7]
#  [ 14067     10]]
# specificity :  0.5882352941176471
# sensitivity :  0.9066729472957911
# accuracy :  0.9066370360542638
# balanced accuracy:  0.5003295798096566
# [[136663      5]
#  [ 14070      7]]
# specificity :  0.5833333333333334
# sensitivity :  0.9066561403275991
# accuracy :  0.9066304023350692
# balanced accuracy:  0.5002303400166703
# [[136666      2]
#  [ 14075      2]]
# specificity :  0.5
# sensitivity :  0.906627924718557
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5000637208613957
# [[136668      0]
#  [ 14075      2]]
# specificity :  1.0
# sensitivity :  0.9066291635432491
# accuracy :  0.9066304023350692
# balanced accuracy:  0.5000710378631811
# [[136668      0]
#  [ 14076      1]]
# specificity :  1.0
# sensitivity :  0.9066231491800669
# accuracy :  0.9066237686158745
# balanced accuracy:  0.5000355189315905
# [[136668      0]
#  [ 14076      1]]
# specificity :  1.0
# sensitivity :  0.9066231491800669
# accuracy :  0.9066237686158745
# balanced accuracy:  0.5000355189315905
# [[136668      0]
#  [ 14076      1]]
# specificity :  1.0
# sensitivity :  0.9066231491800669
# accuracy :  0.9066237686158745
# balanced accuracy:  0.5000355189315905
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# [[136668      0]
#  [ 14077      0]]
# specificity :  nan
# sensitivity :  0.9066171348966798
# accuracy :  0.9066171348966798
# balanced accuracy:  0.5
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars

# %%
sns.set_style("darkgrid")

# plot lines
plt.figure(figsize=(8,4))
plt.plot(df_results2['threshold'], df_results2['accuracy'], label = "accuracy")
plt.plot(df_results2['threshold'], df_results2['balanced accuracy'], label = "balanced acc")
plt.plot(df_results2['threshold'], df_results2['specificity'], label = "specificity")
plt.plot(df_results2['threshold'], df_results2['sensitivity'], label = "sensitivity")
# # single line
plt.vlines(x = 0.6, ymin = 0, ymax = 1.0,
           colors = 'dimgray',
           linestyle='--')
# plt.vlines(x = 0.85, ymin = 0, ymax = 1.0,
#            colors = 'dimgray',
#            linestyle='--')
plt.legend(loc='lower right')
plt.title('Decision Threshold Optimization: XGBoost', fontsize=13, fontweight='bold')
plt.xlabel('Threshold', fontsize=12)
plt.savefig('charts/models/XGBoost/boost_threshold_balanced.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## TabNet Model

# %%
X_train1, X_val1, X_test1, y_train1, y_val1, y_test1 = utilities.process_features(df, 'CVD', QuantileTransformer(output_distribution='uniform'), one_hot=False)
X_train1, y_train1= utilities.resample_data(X_train1, y_train1, 'under')

X_train= X_train1.to_numpy()
X_val= X_val1.to_numpy()
X_test= X_test1.to_numpy()

y_train= y_train1.to_numpy().astype(int)
y_val= y_val1.to_numpy().astype(int)
y_test= y_test1.to_numpy().astype(int)

clf = TabNetClassifier(
    scheduler_fn=torch.optim.lr_scheduler.ReduceLROnPlateau,
    scheduler_params={"mode":'max', # max because default eval metric for binary is AUC
                 "factor":0.1,
                 "patience":1}
)  

# fit model
clf.fit(
    X_train=X_train, y_train=y_train,
    eval_set=[(X_train, y_train), (X_val, y_val)],
    eval_name=['train', 'val'],
    eval_metric=["auc", 'accuracy'],
#     eval_metric=[Recall],

    max_epochs=100 , patience=0,
    batch_size=400,
    virtual_batch_size=128,
    num_workers=0,
    weights=1,
    drop_last=False
)
# Out:
# Device used : cpu
# No early stopping will be performed, last training weights will be used.
# epoch 0  | loss: 0.65246 | train_auc: 0.72117 | train_accuracy: 0.66647 | val_auc: 0.72979 | val_accuracy: 0.57466 |  0:00:16s
# epoch 1  | loss: 0.60887 | train_auc: 0.74239 | train_accuracy: 0.68823 | val_auc: 0.74817 | val_accuracy: 0.68014 |  0:00:32s
# epoch 2  | loss: 0.60288 | train_auc: 0.74417 | train_accuracy: 0.68705 | val_auc: 0.74974 | val_accuracy: 0.64621 |  0:00:48s
# epoch 3  | loss: 0.59732 | train_auc: 0.74892 | train_accuracy: 0.69121 | val_auc: 0.75538 | val_accuracy: 0.69157 |  0:01:04s
# epoch 4  | loss: 0.59945 | train_auc: 0.75021 | train_accuracy: 0.69102 | val_auc: 0.75815 | val_accuracy: 0.67475 |  0:01:20s
# epoch 5  | loss: 0.59741 | train_auc: 0.75121 | train_accuracy: 0.6902  | val_auc: 0.75763 | val_accuracy: 0.71104 |  0:01:36s
# epoch 6  | loss: 0.59914 | train_auc: 0.74824 | train_accuracy: 0.6877  | val_auc: 0.75505 | val_accuracy: 0.68012 |  0:01:52s
# epoch 7  | loss: 0.59574 | train_auc: 0.75079 | train_accuracy: 0.69092 | val_auc: 0.75762 | val_accuracy: 0.69387 |  0:02:09s
# epoch 8  | loss: 0.59525 | train_auc: 0.75213 | train_accuracy: 0.69209 | val_auc: 0.75884 | val_accuracy: 0.68007 |  0:02:25s
# epoch 9  | loss: 0.59066 | train_auc: 0.75266 | train_accuracy: 0.69369 | val_auc: 0.75923 | val_accuracy: 0.69392 |  0:02:41s
# epoch 10 | loss: 0.58992 | train_auc: 0.75279 | train_accuracy: 0.69365 | val_auc: 0.75918 | val_accuracy: 0.6916  |  0:02:57s
# epoch 11 | loss: 0.59256 | train_auc: 0.75284 | train_accuracy: 0.69363 | val_auc: 0.75922 | val_accuracy: 0.69263 |  0:03:13s
# epoch 12 | loss: 0.5921  | train_auc: 0.75283 | train_accuracy: 0.6935  | val_auc: 0.75932 | val_accuracy: 0.69188 |  0:03:29s
# epoch 13 | loss: 0.59244 | train_auc: 0.7528  | train_accuracy: 0.6935  | val_auc: 0.75928 | val_accuracy: 0.691   |  0:03:45s
# epoch 14 | loss: 0.59375 | train_auc: 0.75286 | train_accuracy: 0.69384 | val_auc: 0.75922 | val_accuracy: 0.69213 |  0:04:01s
# epoch 15 | loss: 0.5951  | train_auc: 0.75285 | train_accuracy: 0.69371 | val_auc: 0.75923 | val_accuracy: 0.69271 |  0:04:17s
# epoch 16 | loss: 0.59164 | train_auc: 0.75285 | train_accuracy: 0.69382 | val_auc: 0.75921 | val_accuracy: 0.69453 |  0:04:33s
# epoch 17 | loss: 0.59154 | train_auc: 0.75283 | train_accuracy: 0.69381 | val_auc: 0.75933 | val_accuracy: 0.69435 |  0:04:49s
# epoch 18 | loss: 0.59279 | train_auc: 0.75285 | train_accuracy: 0.69381 | val_auc: 0.75929 | val_accuracy: 0.69269 |  0:05:05s
# epoch 19 | loss: 0.59413 | train_auc: 0.75286 | train_accuracy: 0.69347 | val_auc: 0.75917 | val_accuracy: 0.69223 |  0:05:21s
# epoch 20 | loss: 0.58954 | train_auc: 0.75283 | train_accuracy: 0.69358 | val_auc: 0.75927 | val_accuracy: 0.69268 |  0:05:38s
# epoch 21 | loss: 0.59521 | train_auc: 0.75283 | train_accuracy: 0.69371 | val_auc: 0.75932 | val_accuracy: 0.69236 |  0:05:54s
# epoch 22 | loss: 0.5942  | train_auc: 0.75282 | train_accuracy: 0.69371 | val_auc: 0.75926 | val_accuracy: 0.69283 |  0:06:10s
# epoch 23 | loss: 0.58933 | train_auc: 0.75284 | train_accuracy: 0.69376 | val_auc: 0.75929 | val_accuracy: 0.69175 |  0:06:26s
# epoch 24 | loss: 0.58807 | train_auc: 0.75285 | train_accuracy: 0.69371 | val_auc: 0.75924 | val_accuracy: 0.69223 |  0:06:42s
# epoch 25 | loss: 0.58997 | train_auc: 0.75285 | train_accuracy: 0.69387 | val_auc: 0.7592  | val_accuracy: 0.69346 |  0:06:59s
# epoch 26 | loss: 0.58815 | train_auc: 0.75287 | train_accuracy: 0.69376 | val_auc: 0.75923 | val_accuracy: 0.69213 |  0:07:15s
# epoch 27 | loss: 0.59141 | train_auc: 0.75285 | train_accuracy: 0.69344 | val_auc: 0.75923 | val_accuracy: 0.69125 |  0:07:30s
# epoch 28 | loss: 0.59614 | train_auc: 0.7528  | train_accuracy: 0.69347 | val_auc: 0.7593  | val_accuracy: 0.69221 |  0:07:46s
# epoch 29 | loss: 0.59363 | train_auc: 0.75283 | train_accuracy: 0.69366 | val_auc: 0.75936 | val_accuracy: 0.69253 |  0:08:03s
# epoch 30 | loss: 0.59338 | train_auc: 0.75285 | train_accuracy: 0.69392 | val_auc: 0.7593  | val_accuracy: 0.69268 |  0:08:19s
# epoch 31 | loss: 0.5936  | train_auc: 0.75279 | train_accuracy: 0.69379 | val_auc: 0.75926 | val_accuracy: 0.69324 |  0:08:34s
# epoch 32 | loss: 0.59426 | train_auc: 0.75284 | train_accuracy: 0.69385 | val_auc: 0.75926 | val_accuracy: 0.69302 |  0:08:50s
# epoch 33 | loss: 0.59245 | train_auc: 0.75286 | train_accuracy: 0.69365 | val_auc: 0.75928 | val_accuracy: 0.6921  |  0:09:07s
# epoch 34 | loss: 0.59472 | train_auc: 0.75286 | train_accuracy: 0.69341 | val_auc: 0.75931 | val_accuracy: 0.69166 |  0:09:22s
# epoch 35 | loss: 0.59324 | train_auc: 0.75283 | train_accuracy: 0.69377 | val_auc: 0.75934 | val_accuracy: 0.69291 |  0:09:38s
# epoch 36 | loss: 0.59308 | train_auc: 0.75284 | train_accuracy: 0.69377 | val_auc: 0.75936 | val_accuracy: 0.69326 |  0:09:54s
# epoch 37 | loss: 0.59232 | train_auc: 0.75277 | train_accuracy: 0.69368 | val_auc: 0.75932 | val_accuracy: 0.69231 |  0:10:11s
# epoch 38 | loss: 0.59064 | train_auc: 0.75282 | train_accuracy: 0.69352 | val_auc: 0.75927 | val_accuracy: 0.69225 |  0:10:27s
# epoch 39 | loss: 0.59376 | train_auc: 0.75287 | train_accuracy: 0.69387 | val_auc: 0.7593  | val_accuracy: 0.69273 |  0:10:42s
# epoch 40 | loss: 0.59217 | train_auc: 0.75281 | train_accuracy: 0.69377 | val_auc: 0.75923 | val_accuracy: 0.69196 |  0:10:59s
# epoch 41 | loss: 0.59104 | train_auc: 0.75283 | train_accuracy: 0.69369 | val_auc: 0.75929 | val_accuracy: 0.69246 |  0:11:15s
# epoch 42 | loss: 0.59615 | train_auc: 0.75284 | train_accuracy: 0.69366 | val_auc: 0.75919 | val_accuracy: 0.69362 |  0:11:31s
# epoch 43 | loss: 0.5957  | train_auc: 0.75285 | train_accuracy: 0.6936  | val_auc: 0.75934 | val_accuracy: 0.69183 |  0:11:47s
# epoch 44 | loss: 0.59114 | train_auc: 0.75283 | train_accuracy: 0.69387 | val_auc: 0.7593  | val_accuracy: 0.69276 |  0:12:04s
# epoch 45 | loss: 0.59195 | train_auc: 0.75284 | train_accuracy: 0.69382 | val_auc: 0.75935 | val_accuracy: 0.69244 |  0:12:20s
# epoch 46 | loss: 0.59376 | train_auc: 0.75281 | train_accuracy: 0.69389 | val_auc: 0.75932 | val_accuracy: 0.69324 |  0:12:38s
# epoch 47 | loss: 0.59207 | train_auc: 0.75282 | train_accuracy: 0.69373 | val_auc: 0.75936 | val_accuracy: 0.69281 |  0:12:55s
# epoch 48 | loss: 0.59152 | train_auc: 0.75285 | train_accuracy: 0.69345 | val_auc: 0.7593  | val_accuracy: 0.69108 |  0:13:11s
# epoch 49 | loss: 0.5915  | train_auc: 0.75281 | train_accuracy: 0.69405 | val_auc: 0.75928 | val_accuracy: 0.69208 |  0:13:27s
# epoch 50 | loss: 0.59142 | train_auc: 0.75281 | train_accuracy: 0.69377 | val_auc: 0.75935 | val_accuracy: 0.69244 |  0:13:43s
# epoch 51 | loss: 0.5923  | train_auc: 0.75281 | train_accuracy: 0.69379 | val_auc: 0.75926 | val_accuracy: 0.69268 |  0:13:58s
# epoch 52 | loss: 0.59384 | train_auc: 0.75283 | train_accuracy: 0.69371 | val_auc: 0.75928 | val_accuracy: 0.69258 |  0:14:14s
# epoch 53 | loss: 0.59316 | train_auc: 0.7528  | train_accuracy: 0.69371 | val_auc: 0.75933 | val_accuracy: 0.69215 |  0:14:30s
# epoch 54 | loss: 0.59511 | train_auc: 0.75283 | train_accuracy: 0.69376 | val_auc: 0.75931 | val_accuracy: 0.69234 |  0:14:46s
# epoch 55 | loss: 0.59405 | train_auc: 0.75284 | train_accuracy: 0.69352 | val_auc: 0.75919 | val_accuracy: 0.692   |  0:15:01s
# epoch 56 | loss: 0.59286 | train_auc: 0.75287 | train_accuracy: 0.69376 | val_auc: 0.75938 | val_accuracy: 0.69251 |  0:15:17s
# epoch 57 | loss: 0.59351 | train_auc: 0.75283 | train_accuracy: 0.69393 | val_auc: 0.75931 | val_accuracy: 0.69264 |  0:15:33s
# epoch 58 | loss: 0.59599 | train_auc: 0.75286 | train_accuracy: 0.69353 | val_auc: 0.75927 | val_accuracy: 0.6912  |  0:15:49s
# epoch 59 | loss: 0.59578 | train_auc: 0.75284 | train_accuracy: 0.69368 | val_auc: 0.75931 | val_accuracy: 0.69246 |  0:16:06s
# epoch 60 | loss: 0.59316 | train_auc: 0.75281 | train_accuracy: 0.69347 | val_auc: 0.75927 | val_accuracy: 0.69173 |  0:16:23s
# epoch 61 | loss: 0.59349 | train_auc: 0.75281 | train_accuracy: 0.69345 | val_auc: 0.75926 | val_accuracy: 0.69147 |  0:16:41s
# epoch 62 | loss: 0.59342 | train_auc: 0.75282 | train_accuracy: 0.69376 | val_auc: 0.75921 | val_accuracy: 0.69415 |  0:16:57s
# epoch 63 | loss: 0.59217 | train_auc: 0.75282 | train_accuracy: 0.69384 | val_auc: 0.75928 | val_accuracy: 0.69324 |  0:17:16s
# epoch 64 | loss: 0.58937 | train_auc: 0.75281 | train_accuracy: 0.69387 | val_auc: 0.75932 | val_accuracy: 0.69346 |  0:17:35s
# epoch 65 | loss: 0.59104 | train_auc: 0.7529  | train_accuracy: 0.69357 | val_auc: 0.75934 | val_accuracy: 0.69084 |  0:17:54s
# epoch 66 | loss: 0.59507 | train_auc: 0.75283 | train_accuracy: 0.69384 | val_auc: 0.75941 | val_accuracy: 0.69347 |  0:18:12s
# epoch 67 | loss: 0.59345 | train_auc: 0.75287 | train_accuracy: 0.6935  | val_auc: 0.75932 | val_accuracy: 0.6916  |  0:18:28s
# epoch 68 | loss: 0.59171 | train_auc: 0.75285 | train_accuracy: 0.69349 | val_auc: 0.7593  | val_accuracy: 0.69128 |  0:18:43s
# epoch 69 | loss: 0.59242 | train_auc: 0.75288 | train_accuracy: 0.69368 | val_auc: 0.75934 | val_accuracy: 0.6916  |  0:19:00s
# epoch 70 | loss: 0.5921  | train_auc: 0.75282 | train_accuracy: 0.69373 | val_auc: 0.75929 | val_accuracy: 0.69218 |  0:19:18s
# epoch 71 | loss: 0.59079 | train_auc: 0.75285 | train_accuracy: 0.69365 | val_auc: 0.75929 | val_accuracy: 0.69205 |  0:19:38s
# epoch 72 | loss: 0.59129 | train_auc: 0.75283 | train_accuracy: 0.69376 | val_auc: 0.75935 | val_accuracy: 0.69294 |  0:19:56s
# epoch 73 | loss: 0.59547 | train_auc: 0.75285 | train_accuracy: 0.694   | val_auc: 0.75933 | val_accuracy: 0.69392 |  0:20:15s
# epoch 74 | loss: 0.59076 | train_auc: 0.75276 | train_accuracy: 0.69379 | val_auc: 0.75927 | val_accuracy: 0.69404 |  0:20:32s
# epoch 75 | loss: 0.59392 | train_auc: 0.75283 | train_accuracy: 0.69376 | val_auc: 0.75924 | val_accuracy: 0.69309 |  0:20:48s
# epoch 76 | loss: 0.59347 | train_auc: 0.75286 | train_accuracy: 0.6935  | val_auc: 0.75928 | val_accuracy: 0.69087 |  0:21:07s
# epoch 77 | loss: 0.59074 | train_auc: 0.75282 | train_accuracy: 0.69361 | val_auc: 0.75932 | val_accuracy: 0.69117 |  0:21:27s
# epoch 78 | loss: 0.59284 | train_auc: 0.75283 | train_accuracy: 0.69373 | val_auc: 0.7593  | val_accuracy: 0.69082 |  0:21:45s
# epoch 79 | loss: 0.59151 | train_auc: 0.75287 | train_accuracy: 0.69361 | val_auc: 0.75935 | val_accuracy: 0.69229 |  0:22:01s
# epoch 80 | loss: 0.5931  | train_auc: 0.75288 | train_accuracy: 0.69355 | val_auc: 0.75921 | val_accuracy: 0.6915  |  0:22:17s
# epoch 81 | loss: 0.59574 | train_auc: 0.75282 | train_accuracy: 0.69358 | val_auc: 0.75934 | val_accuracy: 0.69243 |  0:22:33s
# epoch 82 | loss: 0.59235 | train_auc: 0.75284 | train_accuracy: 0.69363 | val_auc: 0.75928 | val_accuracy: 0.69233 |  0:22:48s
# epoch 83 | loss: 0.59077 | train_auc: 0.75282 | train_accuracy: 0.69365 | val_auc: 0.75927 | val_accuracy: 0.69342 |  0:23:04s
# epoch 84 | loss: 0.59481 | train_auc: 0.75285 | train_accuracy: 0.69376 | val_auc: 0.7593  | val_accuracy: 0.69268 |  0:23:20s
# epoch 85 | loss: 0.58986 | train_auc: 0.75288 | train_accuracy: 0.69393 | val_auc: 0.75922 | val_accuracy: 0.69344 |  0:23:36s
# epoch 86 | loss: 0.59103 | train_auc: 0.75282 | train_accuracy: 0.69361 | val_auc: 0.75935 | val_accuracy: 0.69132 |  0:23:51s
# epoch 87 | loss: 0.59473 | train_auc: 0.75286 | train_accuracy: 0.69381 | val_auc: 0.75926 | val_accuracy: 0.69385 |  0:24:07s
# epoch 88 | loss: 0.59235 | train_auc: 0.75281 | train_accuracy: 0.6936  | val_auc: 0.75922 | val_accuracy: 0.69205 |  0:24:22s
# epoch 89 | loss: 0.59211 | train_auc: 0.75286 | train_accuracy: 0.69382 | val_auc: 0.75928 | val_accuracy: 0.69248 |  0:24:37s
# epoch 90 | loss: 0.58985 | train_auc: 0.75283 | train_accuracy: 0.69365 | val_auc: 0.75934 | val_accuracy: 0.69213 |  0:24:52s
# epoch 91 | loss: 0.59356 | train_auc: 0.75279 | train_accuracy: 0.69379 | val_auc: 0.75935 | val_accuracy: 0.69301 |  0:25:07s
# epoch 92 | loss: 0.59051 | train_auc: 0.75288 | train_accuracy: 0.69361 | val_auc: 0.75923 | val_accuracy: 0.69205 |  0:25:22s
# epoch 93 | loss: 0.59112 | train_auc: 0.75285 | train_accuracy: 0.69377 | val_auc: 0.75915 | val_accuracy: 0.69314 |  0:25:37s
# epoch 94 | loss: 0.59155 | train_auc: 0.75278 | train_accuracy: 0.69357 | val_auc: 0.7593  | val_accuracy: 0.69213 |  0:25:52s
# epoch 95 | loss: 0.59309 | train_auc: 0.75288 | train_accuracy: 0.694   | val_auc: 0.75929 | val_accuracy: 0.69327 |  0:26:08s
# epoch 96 | loss: 0.59245 | train_auc: 0.7528  | train_accuracy: 0.69382 | val_auc: 0.75927 | val_accuracy: 0.69294 |  0:26:23s
# epoch 97 | loss: 0.59394 | train_auc: 0.7528  | train_accuracy: 0.69357 | val_auc: 0.75925 | val_accuracy: 0.69201 |  0:26:38s
# epoch 98 | loss: 0.59189 | train_auc: 0.75284 | train_accuracy: 0.6936  | val_auc: 0.75922 | val_accuracy: 0.6918  |  0:26:54s
# epoch 99 | loss: 0.59579 | train_auc: 0.75286 | train_accuracy: 0.69381 | val_auc: 0.75919 | val_accuracy: 0.69198 |  0:27:10s

# %%
# loaded_clf = TabNetClassifier()
# loaded_clf.load_model('saved_models/binary_tabnet_model_1.zip')
# Out:
# Device used : cpu
# Device used : cpu

# %%
y_tabnet_preds = clf.predict_proba(X_test)

# %%
y_tabnet_preds
# Out:
# array([[0.60596454, 0.39403543],
#        [0.6163614 , 0.38363868],
#        [0.66703826, 0.3329617 ],
#        ...,
#        [0.5151588 , 0.48484123],
#        [0.73119426, 0.2688057 ],
#        [0.45884317, 0.5411569 ]], dtype=float32)

# %%
test_thresholds=np.arange(0,1,0.02)
df_results3 = pd.DataFrame(columns = ['threshold', 'specificity', 'sensitivity', 'accuracy', 'balanced accuracy'])
for threshold in test_thresholds:
    mat, sens,spec, acc, bal = fh.confusion_eval2(y_tabnet_preds[:,1], X_test, y_test, threshold=threshold)
    
    df_new = pd.DataFrame({'threshold':threshold, 'specificity':spec, 'sensitivity':sens, 'accuracy':acc, 'balanced accuracy':bal}, index=[0])
    df_results3 = pd.concat([df_results3,df_new])
# Out:
# [[    0 91183]
#  [    0  9314]]
# specificity :  0.09267938346418302
# sensitivity :  nan
# accuracy :  0.09267938346418302
# balanced accuracy:  0.5
# [[    0 91183]
#  [    0  9314]]
# specificity :  0.09267938346418302
# sensitivity :  nan
# accuracy :  0.09267938346418302
# balanced accuracy:  0.5
# [[    0 91183]
#  [    0  9314]]
# specificity :  0.09267938346418302
# sensitivity :  nan
# accuracy :  0.09267938346418302
# balanced accuracy:  0.5
# [[    0 91183]
#  [    0  9314]]
# specificity :  0.09267938346418302
# sensitivity :  nan
# accuracy :  0.09267938346418302
# balanced accuracy:  0.5
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# [[    0 91183]
#  [    0  9314]]
# specificity :  0.09267938346418302
# sensitivity :  nan
# accuracy :  0.09267938346418302
# balanced accuracy:  0.5
# [[   71 91112]
#  [    0  9314]]
# specificity :  0.09274490669746878
# sensitivity :  1.0
# accuracy :  0.093385872215091
# balanced accuracy:  0.500389326957876
# [[  824 90359]
#  [   13  9301]]
# specificity :  0.0933273128637367
# sensitivity :  0.984468339307049
# accuracy :  0.10074927609779397
# balanced accuracy:  0.5038205119347534
# [[ 3300 87883]
#  [   55  9259]]
# specificity :  0.09531407630067325
# sensitivity :  0.9836065573770492
# accuracy :  0.12496890454441426
# balanced accuracy:  0.5151429337672289
# [[ 6928 84255]
#  [  132  9182]]
# invalid value encountered in longlong_scalars
# specificity :  0.09826942217750997
# sensitivity :  0.9813031161473088
# accuracy :  0.16030329263560106
# balanced accuracy:  0.5309034305876463
# [[10898 80285]
#  [  228  9086]]
# specificity :  0.10166608855221493
# sensitivity :  0.9795074600035952
# accuracy :  0.19885170701612984
# balanced accuracy:  0.547519307042076
#  [ 9312     2]]
# specificity :  0.25
# sensitivity :  0.9073331409407995
# accuracy :  0.9072808143526673
# balanced accuracy:  0.5000744643869233
# [[91183     0]
#  [ 9314     0]]
# specificity :  nan
# sensitivity :  0.907320616535817
# accuracy :  0.907320616535817
# balanced accuracy:  0.5
# [[91183     0]
#  [ 9314     0]]
# specificity :  nan
# sensitivity :  0.907320616535817
# accuracy :  0.907320616535817
# balanced accuracy:  0.5
# [[91183     0]
#  [ 9314     0]]
# specificity :  nan
# sensitivity :  0.907320616535817
# accuracy :  0.907320616535817
# balanced accuracy:  0.5
# [[91183     0]
#  [ 9314     0]]
# specificity :  nan
# sensitivity :  0.907320616535817
# accuracy :  0.907320616535817
# balanced accuracy:  0.5
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars
# invalid value encountered in longlong_scalars

# %%
sns.set_style("darkgrid")

# plot lines
plt.figure(figsize=(8,4))
plt.plot(df_results3['threshold'], df_results3['accuracy'], label = "accuracy")
plt.plot(df_results3['threshold'], df_results3['balanced accuracy'], label = "balanced acc")
plt.plot(df_results3['threshold'], df_results3['specificity'], label = "specificity")
plt.plot(df_results3['threshold'], df_results3['sensitivity'], label = "sensitivity")
# # single line
plt.vlines(x = 0.6, ymin = 0, ymax = 1.0,
           colors = 'dimgray',
           linestyle='--')
# plt.vlines(x = 0.85, ymin = 0, ymax = 1.0,
#            colors = 'dimgray',
#            linestyle='--')
plt.legend(loc='upper left')
plt.title('Decision Threshold Optimization: TabNet', fontsize=13, fontweight='bold')
plt.xlabel('Threshold', fontsize=12)
plt.savefig('charts/models/TabNet/tabnet_threshold_balanced.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Performance at Manually Chosen Decision Thresholds
#
# ***
#
# ### MLP: 0.5
#
# ### XGBoost: 0.6
#
# ### TabNet: 0.6

# %%
out1 = df_results[df_results['threshold'] == 0.5]
out2 = df_results2[df_results2['threshold'] == 0.6]
out3 = df_results3[df_results3['threshold'] == 0.6]

performance_results = pd.DataFrame(columns=['model']+out1.columns.to_list())
performance_results = performance_results.append(out1, ignore_index = True)
performance_results = performance_results.append(out2, ignore_index = True)
performance_results = performance_results.append(out3, ignore_index = True)

performance_results.iloc[0,0] = 'MLP'
performance_results.iloc[1,0] = 'XGBoost'
performance_results.iloc[2,0] = 'TabNet'

# %%
print(tabulate(performance_results, headers='keys', tablefmt='fancy_grid'))
# Out:
# ╒════╤═════════╤═════════════╤═══════════════╤═══════════════╤════════════╤═════════════════════╕
# │    │ model   │   threshold │   specificity │   sensitivity │   accuracy │   balanced accuracy │
# ╞════╪═════════╪═════════════╪═══════════════╪═══════════════╪════════════╪═════════════════════╡
# │  0 │ MLP     │         0.5 │      0.176119 │      0.953517 │   0.672268 │            0.676776 │
# ├────┼─────────┼─────────────┼───────────────┼───────────────┼────────────┼─────────────────────┤
# │  1 │ XGBoost │         0.6 │      0.638655 │      0.907048 │   0.906836 │            0.502542 │
# ├────┼─────────┼─────────────┼───────────────┼───────────────┼────────────┼─────────────────────┤
# │  2 │ TabNet  │         0.6 │      0.217795 │      0.946781 │   0.771993 │            0.678374 │
# ╘════╧═════════╧═════════════╧═══════════════╧═══════════════╧════════════╧═════════════════════╛
